# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
plt.figure(figsize=[4,2])
sns.histplot(tips['tip'],bins=20,kde = True)
plt.show()

# %%
plt.figure(figsize=[4,2])
sns.histplot(tips['total_bill'],bins=20,kde = True)
plt.show()

# %%
plt.figure(figsize=[3,2])
sns.countplot(data=tips,x='time')
plt.show()

# %%
plt.figure(figsize=[3,2])
sns.barplot(data=tips , x = 'sex' , y = 'tip')
plt.show()

# %%
plt.figure(figsize=[3,2])
sns.countplot(data=tips , x = 'sex')
plt.show()

# %%
plt.figure(figsize=[3,2])
sns.histplot(data=tips , x = 'sex',palette='magma')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24380\3910707573.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=tips , x = 'sex',palette='magma')

# %%
plt.figure(figsize=[4,2])
sns.boxplot(data= tips , x='day',y='tip')
plt.show()

# %%
plt.figure(figsize=[6,4])
sns.boxplot(data= tips , x='day',y='tip' ,hue='sex')
plt.show()

# %%
plt.figure(figsize=[8,5])
sns.violinplot(data= tips , x='day',y='tip',)
plt.show()

# %%
plt.figure(figsize=[8,5])
sns.violinplot(data= tips , x='day',y='tip',hue='sex',split='True')
plt.show()

# %%
plt.figure(figsize=[6,4])
sns.boxplot(data= tips , x='day',y='tip' ,hue='sex')
sns.stripplot(data= tips , x='day',y='tip' ,hue='sex')
plt.show()

# %%
plt.figure(figsize=[6,4])
sns.boxplot(data= tips , x='day',y='tip' ,hue='sex')
sns.stripplot(data= tips , x='day',y='tip' ,hue='sex',jitter=0)
plt.show()

# %%
plt.figure(figsize=[6,4])
sns.stripplot(data= tips , x='day',y='tip' ,hue='sex',jitter=0)
plt.show()

# %%
sns.jointplot(data=tips , x='total_bill',y='tip',kind='reg')
plt.show()

# %%
sns.jointplot(data=tips , x='total_bill',y='tip',kind='hex')

# %%
sns.pairplot(data=tips,hue='sex')
plt.show()

# %%
g = sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.boxplot)
plt.show()

# %%
g = sns.PairGrid(data=tips,hue='sex')
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.lineplot)
plt.show()

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',col='sex',row='smoker')
plt.show()

# %%
g = sns.FacetGrid(data=tips , col = 'sex' , row = 'smoker')
g.map(sns.lineplot,'total_bill','tip')
plt.show()

# %%
sns.heatmap(tips[['total_bill', 'tip', 'size']].corr() , cmap= 'coolwarm' , annot=True)
plt.show()
